# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets
import pandas as pd
from sklearn.decomposition import PCA

# %%
data=load_iris()

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
data.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
x=pd.DataFrame(data.data,columns=data.feature_names)
x.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y=pd.Series(data.target)
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Length: 150, dtype: int32

# %%
pca=PCA(n_components=3)
pca=pca.fit_transform(x)
pca
# Out:
# array([[-2.68412563,  0.31939725, -0.02791483],
#        [-2.71414169, -0.17700123, -0.21046427],
#        [-2.88899057, -0.14494943,  0.01790026],
#        [-2.74534286, -0.31829898,  0.03155937],
#        [-2.72871654,  0.32675451,  0.09007924],
#        [-2.28085963,  0.74133045,  0.16867766],
#        [-2.82053775, -0.08946138,  0.25789216],
#        [-2.62614497,  0.16338496, -0.02187932],
#        [-2.88638273, -0.57831175,  0.02075957],
#        [-2.6727558 , -0.11377425, -0.19763272],
#        [-2.50694709,  0.6450689 , -0.07531801],
#        [-2.61275523,  0.01472994,  0.10215026],
#        [-2.78610927, -0.235112  , -0.20684443],
#        [-3.22380374, -0.51139459,  0.06129967],
#        [-2.64475039,  1.17876464, -0.15162752],
#        [-2.38603903,  1.33806233,  0.2777769 ],
#        [-2.62352788,  0.81067951,  0.13818323],
#        [-2.64829671,  0.31184914,  0.02666832],
#        [-2.19982032,  0.87283904, -0.12030552],
#        [-2.5879864 ,  0.51356031,  0.21366517],
# ...

# %%
data=pd.DataFrame(pca,columns=["n_comp_1","n_comp_2","n_comp3"])

# %%
data.head()
# Out:
#    n_comp_1  n_comp_2   n_comp3
# 0 -2.684126  0.319397 -0.027915
# 1 -2.714142 -0.177001 -0.210464
# 2 -2.888991 -0.144949  0.017900
# 3 -2.745343 -0.318299  0.031559
# 4 -2.728717  0.326755  0.090079

# %%
x_val=data["n_comp_1"]
y_val=data["n_comp_2"]
z_val=data["n_comp3"]

da=pd.DataFrame(y)
data=pd.concat([data,],axis=1)
data
# Out:
#      n_comp_1  n_comp_2   n_comp3  target
# 0   -2.684126  0.319397 -0.027915       0
# 1   -2.714142 -0.177001 -0.210464       0
# 2   -2.888991 -0.144949  0.017900       0
# 3   -2.745343 -0.318299  0.031559       0
# 4   -2.728717  0.326755  0.090079       0
# ..        ...       ...       ...     ...
# 145  1.944110  0.187532  0.177825       2
# 146  1.527167 -0.375317 -0.121898       2
# 147  1.764346  0.078859  0.130482       2
# 148  1.900942  0.116628  0.723252       2
# 149  1.390189 -0.282661  0.362910       2
#
# [150 rows x 4 columns]

# %%
data.columns=['n_comp_1', 'n_comp_2', 'n_comp3', "target"]
finalDf=data.copy()

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3 component PCA', fontsize = 20)

targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'n_comp_1']
               , finalDf.loc[indicesToKeep, 'n_comp_2']
               , finalDf.loc[indicesToKeep, 'n_comp3']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()
plt.show()
